# %%
# !pip install leafmap
# Out:
# Collecting leafmap
#   Downloading leafmap-0.10.5-py2.py3-none-any.whl (163 kB)
#      -------------------------------------- 163.2/163.2 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: xyzservices in c:\python39\lib\site-packages (from leafmap) (2022.6.0)
# Collecting scooby
#   Downloading scooby-0.6.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: ipyleaflet>=0.17.0 in c:\python39\lib\site-packages (from leafmap) (0.17.1)
# Requirement already satisfied: colour in c:\python39\lib\site-packages (from leafmap) (0.1.5)
# Collecting folium>=0.11.0
#   Downloading folium-0.12.1.post1-py2.py3-none-any.whl (95 kB)
#      ---------------------------------------- 95.0/95.0 kB 5.3 MB/s eta 0:00:00
# Collecting pystac-client
#   Downloading pystac_client-0.5.0-py3-none-any.whl (29 kB)
# Collecting ipyevents
#   Downloading ipyevents-2.0.1-py2.py3-none-any.whl (130 kB)
#      -------------------------------------- 130.5/130.5 kB 3.9 MB/s eta 0:00:00
# Collecting whiteboxgui>=0.6.0
#   Downloading whiteboxgui-0.7.0-py2.py3-none-any.whl (99 kB)
#      ---------------------------------------- 99.8/99.8 kB 5.6 MB/s eta 0:00:00
# Collecting ipysheet
#   Downloading ipysheet-0.5.0-py2.py3-none-any.whl (3.8 MB)
#      ---------------------------------------- 3.8/3.8 MB 6.6 MB/s eta 0:00:00
# Collecting ipyfilechooser>=0.6.0
#   Downloading ipyfilechooser-0.6.0-py3-none-any.whl (11 kB)
# Collecting pyshp>=2.1.3
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#      ---------------------------------------- 46.5/46.5 kB ? eta 0:00:00
# Collecting bqplot
#   Downloading bqplot-0.12.36-py2.py3-none-any.whl (1.2 MB)
#      ---------------------------------------- 1.2/1.2 MB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in c:\python39\lib\site-packages (from leafmap) (3.5.2)
# Collecting pycrs
#   Downloading PyCRS-1.0.2.tar.gz (36 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy in c:\python39\lib\site-packages (from leafmap) (1.19.4)
# Collecting geojson
#   Downloading geojson-2.5.0-py2.py3-none-any.whl (14 kB)
# Collecting gdown
#   Downloading gdown-4.5.1.tar.gz (14 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting python-box
#   Downloading python_box-6.0.2-cp39-cp39-win_amd64.whl (941 kB)
#      -------------------------------------- 941.8/941.8 kB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: jupyterlab>=3.0.0 in c:\python39\lib\site-packages (from leafmap) (3.4.6)
# Requirement already satisfied: pandas in c:\python39\lib\site-packages (from leafmap) (1.4.2)
# Requirement already satisfied: jinja2>=2.9 in c:\python39\lib\site-packages (from folium>=0.11.0->leafmap) (3.1.2)
# Requirement already satisfied: requests in c:\python39\lib\site-packages (from folium>=0.11.0->leafmap) (2.28.1)
# Requirement already satisfied: branca>=0.3.0 in c:\python39\lib\site-packages (from folium>=0.11.0->leafmap) (0.5.0)
# Requirement already satisfied: ipywidgets in c:\python39\lib\site-packages (from ipyfilechooser>=0.6.0->leafmap) (8.0.2)
# Requirement already satisfied: traittypes<3,>=0.2.1 in c:\python39\lib\site-packages (from ipyleaflet>=0.17.0->leafmap) (0.2.1)
# Requirement already satisfied: packaging in c:\python39\lib\site-packages (from jupyterlab>=3.0.0->leafmap) (21.3)
# Requirement already satisfied: tornado>=6.1.0 in c:\python39\lib\site-packages (from jupyterlab>=3.0.0->leafmap) (6.1)
# Requirement already satisfied: jupyter-server~=1.16 in c:\python39\lib\site-packages (from jupyterlab>=3.0.0->leafmap) (1.18.1)
# Requirement already satisfied: ipython in c:\python39\lib\site-packages (from jupyterlab>=3.0.0->leafmap) (8.4.0)
# Requirement already satisfied: jupyter-core in c:\python39\lib\site-packages (from jupyterlab>=3.0.0->leafmap) (4.10.0)
# Requirement already satisfied: notebook<7 in c:\python39\lib\site-packages (from jupyterlab>=3.0.0->leafmap) (6.4.12)
# Requirement already satisfied: jupyterlab-server~=2.10 in c:\python39\lib\site-packages (from jupyterlab>=3.0.0->leafmap) (2.15.1)
# Requirement already satisfied: nbclassic in c:\python39\lib\site-packages (from jupyterlab>=3.0.0->leafmap) (0.4.3)
# Collecting ipytree
#   Downloading ipytree-0.2.2-py2.py3-none-any.whl (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 7.4 MB/s eta 0:00:00
# Collecting whitebox
#   Downloading whitebox-2.1.4-py2.py3-none-any.whl (75 kB)
#      ---------------------------------------- 76.0/76.0 kB ? eta 0:00:00
# Requirement already satisfied: traitlets>=4.3.0 in c:\python39\lib\site-packages (from bqplot->leafmap) (5.3.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\python39\lib\site-packages (from pandas->leafmap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\python39\lib\site-packages (from pandas->leafmap) (2022.1)
# Requirement already satisfied: beautifulsoup4 in c:\python39\lib\site-packages (from gdown->leafmap) (4.11.1)
# Collecting tqdm
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.5/78.5 kB ? eta 0:00:00
# Requirement already satisfied: six in c:\python39\lib\site-packages (from gdown->leafmap) (1.15.0)
# Requirement already satisfied: filelock in c:\users\klauspopp\appdata\roaming\python\python39\site-packages (from gdown->leafmap) (3.0.12)
# Collecting ipywidgets
#   Downloading ipywidgets-7.7.2-py2.py3-none-any.whl (123 kB)
#      -------------------------------------- 123.4/123.4 kB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: pillow>=6.2.0 in c:\python39\lib\site-packages (from matplotlib->leafmap) (8.0.1)
# Requirement already satisfied: cycler>=0.10 in c:\python39\lib\site-packages (from matplotlib->leafmap) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python39\lib\site-packages (from matplotlib->leafmap) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python39\lib\site-packages (from matplotlib->leafmap) (4.33.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\python39\lib\site-packages (from matplotlib->leafmap) (2.4.7)
# Collecting pystac>=1.4.0
#   Downloading pystac-1.6.1-py3-none-any.whl (146 kB)
#      -------------------------------------- 146.0/146.0 kB 4.4 MB/s eta 0:00:00
# Collecting widgetsnbextension~=3.6.0
#   Downloading widgetsnbextension-3.6.1-py2.py3-none-any.whl (1.6 MB)
#      ---------------------------------------- 1.6/1.6 MB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: ipykernel>=4.5.1 in c:\python39\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->leafmap) (6.13.0)
# Collecting jupyterlab-widgets<3,>=1.0.0
#   Downloading jupyterlab_widgets-1.1.1-py3-none-any.whl (245 kB)
#      -------------------------------------- 245.3/245.3 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\python39\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->leafmap) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\python39\lib\site-packages (from ipython->jupyterlab>=3.0.0->leafmap) (2.12.0)
# Requirement already satisfied: backcall in c:\python39\lib\site-packages (from ipython->jupyterlab>=3.0.0->leafmap) (0.2.0)
# Requirement already satisfied: matplotlib-inline in c:\python39\lib\site-packages (from ipython->jupyterlab>=3.0.0->leafmap) (0.1.3)
# Requirement already satisfied: colorama in c:\python39\lib\site-packages (from ipython->jupyterlab>=3.0.0->leafmap) (0.4.4)
# Requirement already satisfied: jedi>=0.16 in c:\python39\lib\site-packages (from ipython->jupyterlab>=3.0.0->leafmap) (0.18.1)
# Requirement already satisfied: setuptools>=18.5 in c:\python39\lib\site-packages (from ipython->jupyterlab>=3.0.0->leafmap) (49.2.1)
# Requirement already satisfied: stack-data in c:\python39\lib\site-packages (from ipython->jupyterlab>=3.0.0->leafmap) (0.2.0)
# Requirement already satisfied: pickleshare in c:\python39\lib\site-packages (from ipython->jupyterlab>=3.0.0->leafmap) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\python39\lib\site-packages (from ipython->jupyterlab>=3.0.0->leafmap) (3.0.29)
# Requirement already satisfied: decorator in c:\python39\lib\site-packages (from ipython->jupyterlab>=3.0.0->leafmap) (5.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python39\lib\site-packages (from jinja2>=2.9->folium>=0.11.0->leafmap) (2.1.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\python39\lib\site-packages (from jupyter-server~=1.16->jupyterlab>=3.0.0->leafmap) (7.3.1)
# Requirement already satisfied: pyzmq>=17 in c:\python39\lib\site-packages (from jupyter-server~=1.16->jupyterlab>=3.0.0->leafmap) (23.0.0)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\python39\lib\site-packages (from jupyter-server~=1.16->jupyterlab>=3.0.0->leafmap) (7.0.0)
# Requirement already satisfied: argon2-cffi in c:\python39\lib\site-packages (from jupyter-server~=1.16->jupyterlab>=3.0.0->leafmap) (21.3.0)
# Requirement already satisfied: pywinpty in c:\python39\lib\site-packages (from jupyter-server~=1.16->jupyterlab>=3.0.0->leafmap) (2.0.7)
# Requirement already satisfied: terminado>=0.8.3 in c:\python39\lib\site-packages (from jupyter-server~=1.16->jupyterlab>=3.0.0->leafmap) (0.15.0)
# Requirement already satisfied: prometheus-client in c:\python39\lib\site-packages (from jupyter-server~=1.16->jupyterlab>=3.0.0->leafmap) (0.14.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\python39\lib\site-packages (from jupyter-server~=1.16->jupyterlab>=3.0.0->leafmap) (3.6.1)
# Requirement already satisfied: websocket-client in c:\python39\lib\site-packages (from jupyter-server~=1.16->jupyterlab>=3.0.0->leafmap) (1.4.1)
# Requirement already satisfied: nbformat>=5.2.0 in c:\python39\lib\site-packages (from jupyter-server~=1.16->jupyterlab>=3.0.0->leafmap) (5.4.0)
# Requirement already satisfied: Send2Trash in c:\python39\lib\site-packages (from jupyter-server~=1.16->jupyterlab>=3.0.0->leafmap) (1.8.0)
# Requirement already satisfied: pywin32>=1.0 in c:\python39\lib\site-packages (from jupyter-core->jupyterlab>=3.0.0->leafmap) (304)
# Requirement already satisfied: importlib-metadata>=3.6 in c:\python39\lib\site-packages (from jupyterlab-server~=2.10->jupyterlab>=3.0.0->leafmap) (4.11.4)
# Requirement already satisfied: json5 in c:\python39\lib\site-packages (from jupyterlab-server~=2.10->jupyterlab>=3.0.0->leafmap) (0.9.10)
# Requirement already satisfied: babel in c:\python39\lib\site-packages (from jupyterlab-server~=2.10->jupyterlab>=3.0.0->leafmap) (2.10.3)
# Requirement already satisfied: jsonschema>=3.0.1 in c:\python39\lib\site-packages (from jupyterlab-server~=2.10->jupyterlab>=3.0.0->leafmap) (4.5.1)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\python39\lib\site-packages (from notebook<7->jupyterlab>=3.0.0->leafmap) (1.5.5)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\python39\lib\site-packages (from requests->folium>=0.11.0->leafmap) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\python39\lib\site-packages (from requests->folium>=0.11.0->leafmap) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\python39\lib\site-packages (from requests->folium>=0.11.0->leafmap) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python39\lib\site-packages (from requests->folium>=0.11.0->leafmap) (2022.5.18.1)
# Requirement already satisfied: soupsieve>1.2 in c:\python39\lib\site-packages (from beautifulsoup4->gdown->leafmap) (2.3.2.post1)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\python39\lib\site-packages (from nbclassic->jupyterlab>=3.0.0->leafmap) (0.1.0)
# Collecting PySocks!=1.5.7,>=1.5.6
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Requirement already satisfied: Click>=6.0 in c:\python39\lib\site-packages (from whitebox->whiteboxgui>=0.6.0->leafmap) (8.0.4)
# Requirement already satisfied: sniffio>=1.1 in c:\python39\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.16->jupyterlab>=3.0.0->leafmap) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in c:\python39\lib\site-packages (from importlib-metadata>=3.6->jupyterlab-server~=2.10->jupyterlab>=3.0.0->leafmap) (3.8.0)
# Requirement already satisfied: psutil in c:\python39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->leafmap) (5.9.1)
# Requirement already satisfied: debugpy>=1.0 in c:\python39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->leafmap) (1.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\python39\lib\site-packages (from jedi>=0.16->ipython->jupyterlab>=3.0.0->leafmap) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\python39\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab>=3.0.0->leafmap) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\python39\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab>=3.0.0->leafmap) (0.18.1)
# Requirement already satisfied: entrypoints in c:\python39\lib\site-packages (from jupyter-client>=6.1.12->jupyter-server~=1.16->jupyterlab>=3.0.0->leafmap) (0.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\python39\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3.0.0->leafmap) (1.5.0)
# Requirement already satisfied: lxml in c:\python39\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3.0.0->leafmap) (4.9.1)
# Requirement already satisfied: mistune<3,>=2.0.3 in c:\python39\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3.0.0->leafmap) (2.0.4)
# Requirement already satisfied: tinycss2 in c:\python39\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3.0.0->leafmap) (1.1.1)
# Requirement already satisfied: defusedxml in c:\python39\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3.0.0->leafmap) (0.7.1)
# Requirement already satisfied: bleach in c:\python39\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3.0.0->leafmap) (5.0.1)
# Requirement already satisfied: jupyterlab-pygments in c:\python39\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3.0.0->leafmap) (0.2.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\python39\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3.0.0->leafmap) (0.6.7)
# Requirement already satisfied: fastjsonschema in c:\python39\lib\site-packages (from nbformat>=5.2.0->jupyter-server~=1.16->jupyterlab>=3.0.0->leafmap) (2.15.3)
# Requirement already satisfied: wcwidth in c:\python39\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyterlab>=3.0.0->leafmap) (0.2.5)
# Requirement already satisfied: argon2-cffi-bindings in c:\python39\lib\site-packages (from argon2-cffi->jupyter-server~=1.16->jupyterlab>=3.0.0->leafmap) (21.2.0)
# Requirement already satisfied: asttokens in c:\python39\lib\site-packages (from stack-data->ipython->jupyterlab>=3.0.0->leafmap) (2.0.5)
# Requirement already satisfied: pure-eval in c:\python39\lib\site-packages (from stack-data->ipython->jupyterlab>=3.0.0->leafmap) (0.2.2)
# Requirement already satisfied: executing in c:\python39\lib\site-packages (from stack-data->ipython->jupyterlab>=3.0.0->leafmap) (0.8.3)
# Requirement already satisfied: cffi>=1.0.1 in c:\python39\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.16->jupyterlab>=3.0.0->leafmap) (1.14.6)
# Requirement already satisfied: webencodings in c:\python39\lib\site-packages (from bleach->nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab>=3.0.0->leafmap) (0.5.1)
# Requirement already satisfied: pycparser in c:\python39\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.16->jupyterlab>=3.0.0->leafmap) (2.20)
# Using legacy 'setup.py install' for pycrs, since package 'wheel' is not installed.
# Building wheels for collected packages: gdown
#   Building wheel for gdown (pyproject.toml): started
#   Building wheel for gdown (pyproject.toml): finished with status 'done'
#   Created wheel for gdown: filename=gdown-4.5.1-py3-none-any.whl size=14933 sha256=89334b4d083ea306c6bb7a7dbaebb0b40ccde875f9fce56e5904002a140982af
#   Stored in directory: c:\users\klauspopp\appdata\local\pip\cache\wheels\b8\79\f0\b523d25d96b0bbb12bb024b97940d08c4fcd498a00070c8d82
# Successfully built gdown
# Installing collected packages: pycrs, geojson, tqdm, scooby, python-box, PySocks, pyshp, jupyterlab-widgets, whitebox, pystac, pystac-client, gdown, folium, widgetsnbextension, ipywidgets, ipytree, ipysheet, ipyfilechooser, ipyevents, bqplot, whiteboxgui, leafmap
#   Running setup.py install for pycrs: started
#   Running setup.py install for pycrs: finished with status 'done'
#   Attempting uninstall: jupyterlab-widgets
#     Found existing installation: jupyterlab-widgets 3.0.3
#     Uninstalling jupyterlab-widgets-3.0.3:
#       Successfully uninstalled jupyterlab-widgets-3.0.3
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 4.0.3
#     Uninstalling widgetsnbextension-4.0.3:
#       Successfully uninstalled widgetsnbextension-4.0.3
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 8.0.2
#     Uninstalling ipywidgets-8.0.2:
#       Successfully uninstalled ipywidgets-8.0.2
# Successfully installed PySocks-1.7.1 bqplot-0.12.36 folium-0.12.1.post1 gdown-4.5.1 geojson-2.5.0 ipyevents-2.0.1 ipyfilechooser-0.6.0 ipysheet-0.5.0 ipytree-0.2.2 ipywidgets-7.7.2 jupyterlab-widgets-1.1.1 leafmap-0.10.5 pycrs-1.0.2 pyshp-2.3.1 pystac-1.6.1 pystac-client-0.5.0 python-box-6.0.2 scooby-0.6.0 tqdm-4.64.1 whitebox-2.1.4 whiteboxgui-0.7.0 widgetsnbextension-3.6.1

# %%
import leafmap




m = leafmap.Map(center=[0, 0], zoom=2)

in_geojson = 'https://raw.githubusercontent.com/giswqs/leafmap/master/examples/data/cable_geo.geojson'
m.add_geojson(in_geojson, layer_name="Cable lines")

m
# Out:
# Map(center=[0, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text'…

# %%
in_geojson
# Out:
# 'https://raw.githubusercontent.com/giswqs/leafmap/master/examples/data/cable_geo.geojson'
